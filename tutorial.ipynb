# %%
import pleasingmatrixorder
import numpy as np
import pickle
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# We start by loading a matrix

# %%
with open('confusion.pkl','rb') as f:
    confusion=pickle.load(f)
plt.imshow(confusion)

# %% [markdown]
# Let's take a look at it

# %%
plt.gcf().set_size_inches(10,10)
plt.imshow(confusion)

# %% [markdown]
# It is in an *unpleasing order*.  Let's use the hungarian algorithm to get it into a vaguely sensible order for most of the rows and columns, and then add back in the stragglers in places that seem to make sense.

# %%
plt.gcf().set_size_inches(10,10)
posA,posB=pleasingmatrixorder.find_pleasing_order(confusion,mergify=False)
plt.imshow(confusion[np.ix_(posA,posB)])

# %% [markdown]
# That looks much better!  It is still kind of rough around the edges.  There are some stragglers way out away from the diagonal that I don't like.  Let us use the iterative partition merging to get a better order.

# %%
posA2,posB2=pleasingmatrixorder.find_pleasing_order(confusion,mergify=True)
# Out:
# 0/47 1/46 2/45 3/44 4/43 5/42 6/41 7/40 8/39 9/38 10/37 11/36 12/35 13/34 14/33 15/32 16/31 17/30 18/29 19/28 20/27 21/26 22/25 23/24 24/23 25/22 26/21 27/20 28/19 29/18 30/17 31/16 32/15 33/14 34/13 35/12 36/11 37/10 38/9 39/8 40/7 41/6 42/5 43/4 44/3 45/2 46/1

# %%
plt.gcf().set_size_inches(10,10)
plt.imshow(confusion[np.ix_(posA2,posB2)])

# %% [markdown]
# That's better.
